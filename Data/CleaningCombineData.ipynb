# %%
import pandas as pd
import numpy as np

# %%
url = '/Users/VishalDubey/Vishal/College/polsci189fs/FF Project/Data/combineData0018.csv'
df = pd.read_csv(url)

# %%
df.describe()
# Out:
#                 Ht           Wt        Forty     Vertical    BenchReps  \
# count  6218.000000  6218.000000  6046.000000  4796.000000  4212.000000
# mean     73.798971   243.372145     4.783784    32.818599    20.926163
# std       2.621373    45.103814     0.305984     4.213729     6.393679
# min      65.000000   149.000000     4.220000    17.500000     2.000000
# 25%      72.000000   206.000000     4.540000    30.000000    16.000000
# 50%      74.000000   233.000000     4.700000    33.000000    21.000000
# 75%      76.000000   281.000000     4.980000    35.500000    25.000000
# max      82.000000   375.000000     6.050000    46.000000    49.000000
#
#          BroadJump         Cone      Shuttle         Year           AV  \
# count  4754.000000  3993.000000  4063.000000  6218.000000  6218.000000
# mean    113.943837     7.282307     4.390603  2009.041975     5.085719
# std       9.317031     0.422882     0.268836     5.471056     7.546556
# ...

# %%
players = df[ (df['Pos'] != 'RB') & (df['Pos'] != 'TE') & (df['Pos'] != 'WR') & (df['Pos'] != 'QB') ].index

players
# Out:
# Int64Index([   0,    2,    4,    5,    6,    7,    8,    9,   10,   11,
#             ...
#             6201, 6204, 6207, 6210, 6211, 6213, 6214, 6215, 6216, 6217],
#            dtype='int64', length=4134)

# %%
df.drop(players , inplace=True)

# %%
df.describe()
# Out:
#                 Ht           Wt        Forty     Vertical    BenchReps  \
# count  2084.000000  2084.000000  2042.000000  1682.000000  1096.000000
# mean     73.071977   217.123321     4.618335    33.955707    17.875000
# std       2.732181    22.710976     0.180264     3.490273     5.041732
# min      65.000000   149.000000     4.220000    21.500000     3.000000
# 25%      71.000000   201.000000     4.490000    31.500000    14.750000
# 50%      73.000000   215.000000     4.580000    34.000000    18.000000
# 75%      75.000000   229.000000     4.730000    36.000000    21.000000
# max      80.000000   336.000000     5.370000    45.000000    35.000000
#
#          BroadJump         Cone      Shuttle         Year           AV  \
# count  1658.000000  1364.000000  1382.000000  2084.000000  2084.000000
# mean    117.003619     7.061987     4.271715  2009.063820     4.597409
# std       6.990380     0.240409     0.165280     5.477336     7.835173
# ...

# %%
years = df[ (df['Year'] != 2000) & (df['Year'] != 2001) & (df['Year'] != 2002) & (df['Year'] != 2003) & (df['Year'] != 2004) &(df['Year'] != 2005) & (df['Year'] != 2006) & (df['Year'] != 2007) & (df['Year'] != 2008) & (df['Year'] != 2009) & (df['Year'] != 2010) & (df['Year'] != 2011) & (df['Year'] != 2012) & (df['Year'] != 2013) & (df['Year'] != 2014) & (df['Year'] != 2015) & (df['Year'] != 2016) ].index

years
# Out:
# Int64Index([5556, 5559, 5572, 5578, 5583, 5584, 5588, 5593, 5594, 5596,
#             ...
#             6195, 6197, 6199, 6202, 6203, 6205, 6206, 6208, 6209, 6212],
#            dtype='int64', length=233)

# %%
df.drop(years , inplace=True)

# %%
noTeams = df[ df['Team'].isnull() ].index
df.drop(noTeams, inplace=True)

# %%
df
# Out:
#                   Player Pos  Ht   Wt  Forty  Vertical  BenchReps  BroadJump  \
# 1        Shaun Alexander  RB  72  218   4.58       NaN        NaN        NaN
# 18         Anthony Becht  TE  78  270   4.78      33.5        NaN      123.0
# 27             Tom Brady  QB  76  211   5.28      24.5        NaN       99.0
# 36           Marc Bulger  QB  74  208   4.97       NaN        NaN      100.0
# 39       Plaxico Burress  WR  77  231   4.59      33.0        NaN      115.0
# 41        Trung Canidate  RB  71  193   4.41       NaN       18.0        NaN
# 48          Doug Chapman  RB  70  215   4.56      38.5       16.0      128.0
# 58            Chris Cole  WR  72  191   4.37      37.5        NaN      125.0
# 61      Laveranues Coles  WR  71  192   4.41      34.0        NaN      115.0
# 75         JaJuan Dawson  WR  73  199   4.55      34.0        NaN      117.0
# 76             Ron Dayne  RB  71  259   4.65       NaN        NaN        NaN
# ...

# %%
df.to_csv('combine.csv')
