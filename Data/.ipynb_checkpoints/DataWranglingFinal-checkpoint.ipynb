# %%
import numpy as np
import pandas as pd

# %%
combineUrl = '/Users/VishalDubey/Vishal/College/polsci189fs/FF Project/Data/combine.csv'
urls = ['/Users/VishalDubey/Vishal/College/polsci189fs/FF Project/Data/fantasyPointsDataSets/fantasyPoints'+str(x)+'.csv' for x in range(2012, 2019)]
combine = pd.read_csv(combineUrl)

# %%
pts12 = pd.read_csv(urls[0])
pts13 = pd.read_csv(urls[1])
pts14 = pd.read_csv(urls[2])
pts15 = pd.read_csv(urls[3])
pts16 = pd.read_csv(urls[4])
pts17 = pd.read_csv(urls[5])
pts18 = pd.read_csv(urls[6])

# %%
pts18.head()
# Out:
#                   name position  games  points  year
# 0          Todd Gurley       RB     14   313.0  2018
# 1       Saquon Barkley       RB     16   295.0  2018
# 2  Christian McCaffrey       RB     16   279.0  2018
# 3         Alvin Kamara       RB     15   273.0  2018
# 4      Patrick Mahomes       QB     16   417.0  2018

# %%
combine.head()
# Out:
#    Unnamed: 0          Player Pos  Ht   Wt  Forty  Vertical  BenchReps  \
# 0        3278  Arrelious Benn  WR  73  219   4.57      37.0       20.0
# 1        3280     Jahvid Best  RB  70  199   4.34      32.5       18.0
# 2        3287    Sam Bradford  QB  76  236   4.79       NaN        NaN
# 3        3288  Dezmon Briscoe  WR  74  207   4.66      33.0        9.0
# 4        3290   Levi Brown-02  QB  75  229   4.93      31.5       20.0
#
#    BroadJump  Cone  Shuttle  Year    Pfr_ID    AV                  Team  \
# 0      118.0   NaN      NaN  2010  BennAr00   7.0  Tampa Bay Buccaneers
# 1      113.0  6.75     4.17  2010  BestJa00  13.0         Detroit Lions
# 2        NaN   NaN      NaN  2010  BradSa00  21.0        St. Louis Rams
# 3      115.0  7.10     4.57  2010  BrisDe00   4.0    Cincinnati Bengals
# 4      106.0  7.07     4.43  2010  BrowLe00   0.0         Buffalo Bills
#
#    Round   Pick
# 0    2.0   39.0
# 1    1.0   30.0
# 2    1.0    1.0
# 3    6.0  191.0
# 4    7.0  209.0

# %%
combine['Player'] = pd.Series([x.replace('-02', '') for x in combine['Player']])
combine.head()
# Out:
#    Unnamed: 0          Player Pos  Ht   Wt  Forty  Vertical  BenchReps  \
# 0        3278  Arrelious Benn  WR  73  219   4.57      37.0       20.0
# 1        3280     Jahvid Best  RB  70  199   4.34      32.5       18.0
# 2        3287    Sam Bradford  QB  76  236   4.79       NaN        NaN
# 3        3288  Dezmon Briscoe  WR  74  207   4.66      33.0        9.0
# 4        3290      Levi Brown  QB  75  229   4.93      31.5       20.0
#
#    BroadJump  Cone  Shuttle  Year    Pfr_ID    AV                  Team  \
# 0      118.0   NaN      NaN  2010  BennAr00   7.0  Tampa Bay Buccaneers
# 1      113.0  6.75     4.17  2010  BestJa00  13.0         Detroit Lions
# 2        NaN   NaN      NaN  2010  BradSa00  21.0        St. Louis Rams
# 3      115.0  7.10     4.57  2010  BrisDe00   4.0    Cincinnati Bengals
# 4      106.0  7.07     4.43  2010  BrowLe00   0.0         Buffalo Bills
#
#    Round   Pick
# 0    2.0   39.0
# 1    1.0   30.0
# 2    1.0    1.0
# 3    6.0  191.0
# 4    7.0  209.0

# %%
yr2 = pd.Series(['']*len(combine['Player']))

def createToMerge(pts, combine, year):         
    for i in range(len(pts['name'])):
        nm = pts['name'][i]
        tmp = combine['Player'][combine['Player']==nm]
        if(len(tmp)>0):
            if(combine['Year'][tmp.index[0]]==year):
                yr2[tmp.index[0]] = pts['points'][i]

createToMerge(pts12, combine, 2010)
createToMerge(pts13, combine, 2011)
createToMerge(pts14, combine, 2012)
createToMerge(pts15, combine, 2013)
createToMerge(pts16, combine, 2014)
createToMerge(pts17, combine, 2015)
createToMerge(pts18, combine, 2016)

#for i in range(len(yr2)):
#    print("{}\t\t{}\t\t{}".format(yr2[i], combine['Player'][i], combine['Year'][i]))

# %%
combine['yr2'] = yr2
combine
# Out:
#      Unnamed: 0              Player Pos  Ht   Wt  Forty  Vertical  BenchReps  \
# 0          3278      Arrelious Benn  WR  73  219   4.57      37.0       20.0
# 1          3280         Jahvid Best  RB  70  199   4.34      32.5       18.0
# 2          3287        Sam Bradford  QB  76  236   4.79       NaN        NaN
# 3          3288      Dezmon Briscoe  WR  74  207   4.66      33.0        9.0
# 4          3290          Levi Brown  QB  75  229   4.93      31.5       20.0
# 5          3295       Antonio Brown  WR  70  186   4.56      33.5       13.0
# 6          3296          Dez Bryant  WR  74  225   4.52       NaN        NaN
# 7          3302          Nate Byham  TE  76  268   4.97      29.0        NaN
# 8          3306       Sean Canfield  QB  76  223   4.93      29.5        NaN
# 9          3317       Jimmy Clausen  QB  75  222   4.76       NaN        NaN
# 10         3328        Riley Cooper  WR  75  222   4.53      33.0        NaN
# ...

# %%
count = 0
for i in combine.yr2:
    if(isinstance(i, float)):
        count+=1
print(count)
# Out:
# 340
